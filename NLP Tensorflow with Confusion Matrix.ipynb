# %%
import pandas as pd
import numpy as np

# %%
dataframe=pd.read_csv("Training Data 2017 2018.csv", header=0, names=['x','text','date','approval','label'])

# %%
dataframe.head()
# Out:
#    x                                               text        date  approval  \
# 0  0  numerous countries considered meeting would pe...  04/30/2018  41.31839
# 1  1  white house correspondents f dinner dead know ...  04/30/2018  41.31839
# 2  2  headline gkim prepared cede nuclear weapons u ...  04/30/2018  41.31839
# 3  3  white house correspondents f dinner failure la...  04/30/2018  41.31839
# 4  4  gtrump fs triumphs driving critics crazy h tha...  04/30/2018  41.31839
#
#    label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
dataframe=dataframe.drop("x",axis=1)

# %%
dataframe.head()
# Out:
#                                                 text        date  approval  \
# 0  numerous countries considered meeting would pe...  04/30/2018  41.31839
# 1  white house correspondents f dinner dead know ...  04/30/2018  41.31839
# 2  headline gkim prepared cede nuclear weapons u ...  04/30/2018  41.31839
# 3  white house correspondents f dinner failure la...  04/30/2018  41.31839
# 4  gtrump fs triumphs driving critics crazy h tha...  04/30/2018  41.31839
#
#    label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
"""""from sklearn.utils import shuffle
dataframe_s = shuffle(dataframe)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-057e8c159ab9> in <module>
# ----> 1 from sklearn.utils import shuffle
#       2 dataframe_s = shuffle(dataframe)
#
# ~\Anaconda3\envs\tf15\lib\site-packages\sklearn\__init__.py in <module>
#      62 else:
#      63     from . import __check_build
# ---> 64     from .base import clone
#      65     from .utils._show_versions import show_versions
#      66
#
# ~\Anaconda3\envs\tf15\lib\site-packages\sklearn\base.py in <module>
#      11 from scipy import sparse
#      12 from .externals import six
# ---> 13 from .utils.fixes import signature
#      14 from . import __version__
#      15
#
# ~\Anaconda3\envs\tf15\lib\site-packages\sklearn\utils\__init__.py in <module>
#      14 from . import _joblib
#      15 from ..exceptions import DataConversionWarning
# ---> 16 from .fixes import _Sequence as Sequence
#      17 from .deprecation import deprecated
#      18 from .validation import (as_float_array,
#
# ~\Anaconda3\envs\tf15\lib\site-packages\sklearn\utils\fixes.py in <module>
#      90     from ._scipy_sparse_lsqr_backport import lsqr as sparse_lsqr
#      91 else:
# ---> 92     from scipy.sparse.linalg import lsqr as sparse_lsqr  # noqa
#      93
#      94
#
# ~\Anaconda3\envs\tf15\lib\site-packages\scipy\sparse\linalg\__init__.py in <module>
#     116 from .interface import *
#     117 from .eigen import *
# --> 118 from .matfuncs import *
#     119 from ._onenormest import *
#     120 from ._norm import *
#
# ~\Anaconda3\envs\tf15\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\Anaconda3\envs\tf15\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\Anaconda3\envs\tf15\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\Anaconda3\envs\tf15\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\Anaconda3\envs\tf15\lib\importlib\_bootstrap_external.py in get_code(self, fullname)
#
# ~\Anaconda3\envs\tf15\lib\importlib\_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %%
dataframe.dtypes

# %%
max_value=max(dataframe['approval'])
min_value=min(dataframe['approval'])
one_third=(max_value-min_value)/3

# %%
def labeller(value):
    if value<=(min_value+one_third):
        return 0
    elif value>(min_value+one_third) and value<(max_value-one_third):
        return 1
    else:
        return 2

# %%
dataframe['new_label']=dataframe['approval'].apply(labeller)

# %%
print(dataframe.groupby(by='new_label').count())
# Out:
#            text  date  approval  label
# new_label
# 0          1818  1819      1819   1819
# 1           797   799       799    799
# 2           217   217       217    217

# %%
""""for idx, row in dataframe_s.iterrows():
    if  dataframe_s.loc[idx,'label'] == -2:
        dataframe_s.loc[idx,'new'] = 0
    elif  dataframe_s.loc[idx,'label'] == -1:
        dataframe_s.loc[idx,'new'] = 0
    elif  dataframe_s.loc[idx,'label'] == 0:
        dataframe_s.loc[idx,'new'] = 1
    elif  dataframe_s.loc[idx,'label'] == 1:
        dataframe_s.loc[idx,'new'] = 1
    elif  dataframe_s.loc[idx,'label'] == 2:
        dataframe_s.loc[idx,'new'] = 1

# %%
print(dataframe.head())
# Out:
#                                                 text        date  approval  \
# 0  numerous countries considered meeting would pe...  04/30/2018  41.31839
# 1  white house correspondents f dinner dead know ...  04/30/2018  41.31839
# 2  headline gkim prepared cede nuclear weapons u ...  04/30/2018  41.31839
# 3  white house correspondents f dinner failure la...  04/30/2018  41.31839
# 4  gtrump fs triumphs driving critics crazy h tha...  04/30/2018  41.31839
#
#    label  new_label
# 0      1          1
# 1      1          1
# 2      1          1
# 3      1          1
# 4      1          1

# %%
dataframe_s=dataframe[['text','new_label']]

# %%
dataframe_s
# Out:
#                                                    text  new_label
# 0     numerous countries considered meeting would pe...          1
# 1     white house correspondents f dinner dead know ...          1
# 2     headline gkim prepared cede nuclear weapons u ...          1
# 3     white house correspondents f dinner failure la...          1
# 4     gtrump fs triumphs driving critics crazy h tha...          1
# 5     got recent poll much higher president time wel...          1
# 6     washington michigan big success washington c f...          1
# 7     great evening last night washington michigan e...          1
# 8        join live washington michigan pme foxnews maga          1
# 9     secret service informed senator jon tester fs ...          1
# 10    look forward great state michigan tonight majo...          1
# 11    long good talk president moon south korea thin...          1
# 12    gclapper lied fraudulent dossier leaks cnn h f...          1
# 13    great people montana stand kind slander talkin...          1
# 14    allegations made senator jon tester admiral do...          1
# 15    house intelligence committee rules collusion t...          1
# 16    house intelligence committee rules collusion t...          1
# 17    urge americans participate takebackday tomorro...          1
# 18    house intelligence committee report released g...          1
# 19    look forward meeting chancellor angela merkel ...          1
# 20    kanye west performed great service black commu...          1
# 21    please forget great help good friend president...          1
# 22    great staff sgt dan nevins incredible wounded ...          1
# 23    korean war end united states great people prou...          1
# 24    furious year missile launches nuclear testing ...          1
# 25    everybody believing going james comey ft defin...          1
# 26    u put together strong bid w canada mexico worl...          1
# 27               loved foxandfriends morning great show          1
# 28                      interviewed foxandfriends enjoy          1
# 29                                                 maga          1
# ...                                                 ...        ...
# 2805  even registered vote dead many long time depen...          1
# 2806  asking major investigation voter fraud includi...          1
# 2807  big day planned national security tomorrow amo...          1
# 2808  chicago fix horrible carnage going shootings k...          1
# 2809  congratulations foxnews number one inauguratio...          1
# 2810  great meeting ford ceo mark fields general mot...          1
# 2811  signing orders move forward construction keyst...          2
# 2812  great meeting automobile industry leaders whit...          2
# 2813  photo delivered yesterday displayed upper lowe...          2
# 2814  meeting top automobile executives concerning j...          2
# 2815  busy week planned heavy focus jobs national se...          2
# 2816  peaceful protests hallmark democracy even alwa...          2
# 2817  wow television ratings million people watched ...          2
# 2818  watched protests yesterday impression election...          2
# 2819  great meeting cia headquarters yesterday packe...          2
# 2820  fantastic day evening washington c thank foxne...          2
# 2821  thank another wonderful evening washington c t...          2
# 2822                                          americans          2
# 2823  americans every city near far small large moun...          2
# 2824                                      time remember          2
# 2825  follow two simple rules buy american hire amer...          2
# 2826  bring back jobs bring back borders bring back ...          2
# 2827  forgotten men women country forgotten longer m...          2
# 2828  january th remembered day people became rulers...          2
# 2829  truly matters party controls government whethe...          2
# 2830  power washington c giving back american people...          2
# 2831  today merely transferring power one administra...          2
# 2832  begins today see swearing movement continues w...          2
# 2833  thank wonderful evening washington c inauguration          2
# 2834  thank joining us lincoln memorial tonight spec...          2
#
# [2835 rows x 2 columns]

# %%
#dataframe_s=dataframe_s.drop('label', axis=1)

# %%
#dataframe_s=dataframe.drop(['Date','approval_date','label'], axis=1)

# %%
from sklearn.utils import shuffle
dataframe_s = shuffle(dataframe_s)

train=dataframe_s.iloc[:1700,:]
cross_eval=dataframe_s.iloc[1701:2401,:]
test=dataframe_s.iloc[2402:2835,:]

# %%
train
# Out:
#                                                    text  new_label
# 377   manufacturing growing fastest pace almost two ...          1
# 1325  nbcnews story totally refuted sec tillerson vp...          0
# 986   president xi china stated upping sanctions nok...          0
# 2418  great book reading enjoyment reasons vote demo...          1
# 671   fact sneaky dianne feinstein numerous occasion...          0
# 1580  manufacturing index rose highest level since e...          0
# 2424                              happy easter everyone          1
# 1277  democrats want massive tax increases soft crim...          0
# 2036  first day office fve taken swift action lift c...          0
# 2687  working dinner tonight prime minister abe japa...          2
# 685              gtrump rally stocks put record books h          0
# 2327  honor host president mahmoud abbas wh today ho...          1
# 1892  republicans never discuss good healthcare bill...          0
# 260   candidate pledged elected would use every lawf...          1
# 1116                 order put conspiracy theories rest          0
# 2511                       happy medalofhonorday heroes          1
# 1606  mexico one highest crime nations world must wa...          0
# 1517  told republicans approve healthcare fast would...          0
# 518   congratulations republic korea magnificent win...          1
# 478   cannot believe badly daca recipients treated d...          1
# 2823  americans every city near far small large moun...          2
# 867   vote cut taxes vote put america first time tak...          0
# 1958                                 make america great          0
# 1777  great veterans connect w va healthcare team an...          0
# 1997                             speaking italy morning          0
# 1728  promised campaign trail provide opportunity am...          0
# 1175  nd amendment strong military isis historic va ...          0
# 2542  honor welcome taoiseach ireland endakennytd wh...          1
# 1552  together show world forces destruction extremi...          0
# 1792  highest stock market ever best economic number...          0
# ...                                                 ...        ...
# 1597  reading false reporting even ferocious anger d...          0
# 1282  fake news time trying hurt one finest people k...          0
# 2145  great numbers economy work including passage m...          0
# 2265  interviewed judgejeanine foxnews p saturday ni...          0
# 749                                       thank maria b          0
# 2392  getting ready visit walter reed medical center...          1
# 352   lowest rated oscars history problem ft stars a...          1
# 485   many signs florida shooter mentally disturbed ...          1
# 757              ivanka trump interviewed foxandfriends          0
# 1773  forget foxconn spending billion dollars top li...          0
# 437   great billy graham dead nobody like missed chr...          0
# 1835  great honor join wonderful veterans amvets pos...          0
# 418   years rebuilding nations finally rebuilding na...          0
# 1019  making working hard tax cuts middle class comp...          0
# 494   big week infrastructure stupidly spending tril...          1
# 2729        enjoy superbowl continue make america great          2
# 678   country rapidly grows stronger smarter want wi...          0
# 2271  james clapper virtually everyone else knowledg...          1
# 2282           democrats ashamed disgrace draintheswamp          1
# 903   happy smallbusinesssaturday great day support ...          0
# 1700  wow senator luther strange picked lot addition...          0
# 556   offered daca wonderful deal including doubling...          0
# 2770  nothing nice searching terrorists enter countr...          2
# 1850  ukrainian efforts sabotage trump campaign quie...          0
# 2553         great optimism america results even better          1
# 721   today great honor sign largest tax cuts reform...          0
# 2037  democrats purposely misstated medicaid new sen...          0
# 1350  must united offering assistance everyone suffe...          0
# 2023  new american energy policy unlock millions job...          0
# 2537      president changed small businesses confidence          1
#
# [1700 rows x 2 columns]

# %%
""""train_test=int(len(test))/int(len(dataframe))
print ("Train size : %d" % len(train))
print ("Test size : %d" % len(test))
print ("Train Test Split is at %s" % str(train_test))

# %%
train=train.dropna()

# %%
test=test.dropna()

# %%
#train=train.drop(columns=['Date'])

# %%
#train['label']=train['label']+2

# %%
#test=test.dropna()
#test['label']=test['label']+2

# %%
import tensorflow as tf

# %%
#!pip install tensorflow_hub
import tensorflow_hub as hub

# %%
train_input_fn=tf.estimator.inputs.pandas_input_fn(train, train['new_label'],num_epochs=None, shuffle=True)

# %%
eval_input_fn=tf.estimator.inputs.pandas_input_fn(cross_eval, cross_eval['new_label'],num_epochs=None, shuffle=True)
predict_train_input_fn=tf.estimator.inputs.pandas_input_fn(train, train['new_label'],shuffle=False)

# %%
predict_test_input_fn=tf.estimator.inputs.pandas_input_fn(test,test['new_label'],shuffle=False)

# %%
run_config=tf.estimator.RunConfig(keep_checkpoint_max=1)

# %%
embedded_text_feature_column=hub.text_embedding_column(key='text',module_spec='https://tfhub.dev/google/nnlm-en-dim128/1',trainable=True)
# Out:
# INFO:tensorflow:Using C:\Users\Admin\AppData\Local\Temp\tfhub_modules to cache modules.

# %%
estimator=tf.estimator.DNNClassifier(
    hidden_units=[200,100,50],
    feature_columns=[embedded_text_feature_column],
    n_classes=5,
    config=run_config,
    optimizer=tf.train.AdagradOptimizer(learning_rate=0.0005))
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Admin\AppData\Local\Temp\tmp_61a80wa
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Admin\\AppData\\Local\\Temp\\tmp_61a80wa', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000002059E0E1470>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
estimator.train(input_fn=train_input_fn,steps=10000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\Admin\AppData\Local\Temp\tmp_61a80wa\model.ckpt.
# INFO:tensorflow:loss = 208.9845, step = 0
# INFO:tensorflow:global_step/sec: 134.506
# INFO:tensorflow:loss = 152.59589, step = 100 (0.773 sec)
# INFO:tensorflow:global_step/sec: 120.207
# INFO:tensorflow:loss = 126.03175, step = 200 (0.804 sec)
# INFO:tensorflow:global_step/sec: 157.536
# INFO:tensorflow:loss = 119.23665, step = 300 (0.634 sec)
# INFO:tensorflow:global_step/sec: 165.523
# INFO:tensorflow:loss = 106.9171, step = 400 (0.602 sec)
# INFO:tensorflow:global_step/sec: 156.765
# INFO:tensorflow:loss = 90.90675, step = 500 (0.641 sec)
# INFO:tensorflow:global_step/sec: 131.473
# INFO:tensorflow:loss = 119.21131, step = 600 (0.760 sec)
# INFO:tensorflow:global_step/sec: 153.689
# INFO:tensorflow:loss = 103.98152, step = 700 (0.651 sec)
# INFO:tensorflow:global_step/sec: 168.489
# INFO:tensorflow:loss = 116.510704, step = 800 (0.592 sec)
# INFO:tensorflow:global_step/sec: 152.68
# INFO:tensorflow:loss = 102.64143, step = 900 (0.655 sec)
# INFO:tensorflow:loss = 1.7689252, step = 9100 (0.596 sec)
# INFO:tensorflow:global_step/sec: 177.116
# INFO:tensorflow:loss = 3.8639352, step = 9200 (0.562 sec)
# INFO:tensorflow:global_step/sec: 178.291
# INFO:tensorflow:loss = 1.8524582, step = 9300 (0.561 sec)
# INFO:tensorflow:global_step/sec: 161.127
# INFO:tensorflow:loss = 1.8356352, step = 9400 (0.623 sec)
# INFO:tensorflow:global_step/sec: 171.715
# INFO:tensorflow:loss = 1.4948585, step = 9500 (0.583 sec)
# INFO:tensorflow:global_step/sec: 170.437
# INFO:tensorflow:loss = 1.4696467, step = 9600 (0.584 sec)
# INFO:tensorflow:global_step/sec: 194.024
# INFO:tensorflow:loss = 2.3068922, step = 9700 (0.531 sec)
# INFO:tensorflow:global_step/sec: 188.029
# INFO:tensorflow:loss = 2.1636596, step = 9800 (0.516 sec)
# INFO:tensorflow:global_step/sec: 199.334
# INFO:tensorflow:loss = 2.420206, step = 9900 (0.502 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into C:\Users\Admin\AppData\Local\Temp\tmp_61a80wa\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.5725523.

# %%
train_eval_result=estimator.evaluate(input_fn=predict_train_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-03-17:01:33
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Admin\AppData\Local\Temp\tmp_61a80wa\model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-03-17:01:34
# INFO:tensorflow:Saving dict for global step 10000: accuracy = 0.99529135, average_loss = 0.020308752, global_step = 10000, loss = 2.4646122
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: C:\Users\Admin\AppData\Local\Temp\tmp_61a80wa\model.ckpt-10000

# %%
print("Training Test Accuracy: {accuracy}".format(**train_eval_result))
# Out:
# Training Test Accuracy: 0.9958799481391907

# %%
test_eval_result=estimator.evaluate(input_fn=predict_test_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-03-14:43:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./output\model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-03-14:43:49
# INFO:tensorflow:Saving dict for global step 10000: accuracy = 0.5833333, average_loss = 1.7264819, global_step = 10000, loss = 186.46005
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: ./output\model.ckpt-10000

# %%
print("Test Training Accuracy: {accuracy}".format(**test_eval_result))
# Out:
# Test Training Accuracy: 0.5833333134651184

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def get_predictions(estimator, input_fn):
  return [x["class_ids"][0] for x in estimator.predict(input_fn=input_fn)]

# Create a confusion matrix on training data.
with tf.Graph().as_default():
  cm = tf.confusion_matrix(train["new_label"],
                           get_predictions(estimator, predict_train_input_fn))
  with tf.Session() as session:
    cm_out = session.run(cm)

# Normalize the confusion matrix so that each row sums to 1.
cm_out = cm_out.astype(float) / cm_out.sum(axis=1)[:, np.newaxis]

sns.heatmap(
    cm_out,
    annot=True,
    xticklabels=['0','1','2'],
    yticklabels=['0','1','2'])
plt.xlabel("Predicted")
plt.ylabel("True")
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./output\model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Text(33.0, 0.5, 'True')

# %%
from IPython.display import clear_output, Image, display, HTML

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = "<stripped %d bytes>"%size
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# %%
gdef = tf.GraphDef()
from google.protobuf import text_format
text_format.Merge(open("./output/graph.pbtxt").read(), gdef)
show_graph(gdef)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-29baa125ff25> in <module>
# ----> 1 gdef = tf.GraphDef()
#       2 from google.protobuf import text_format
#       3 text_format.Merge(open("./output/graph.pbtxt").read(), gdef)
#       4 show_graph(gdef)
#
# NameError: name 'tf' is not defined

# %%
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.6190721087039041&quot;).pbtxt = '';
#           }
#         </script>
#         <link rel=&quot;import&quot; href=&quot;https://tensorboard.appspot.com/tf-graph-basic.build.html&quot; onload=load()>
#         <div style=&quot;height:600px&quot;>
#           <tf-graph-basic id=&quot;graph0.6190721087039041&quot;></tf-graph-basic>
#         </div>
#     "></iframe>
